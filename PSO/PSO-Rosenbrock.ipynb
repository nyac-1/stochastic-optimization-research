# %%
import sys
sys.path.insert(0, '../util')

from layer import *
from plot import *

from __future__ import division
import random
import math
import numpy as np
import pandas as pd
import time

xy = np.mgrid[-1:1:100j, -1:1:100j].reshape(2,-1).T
xyT = xy.T

rosenbrock = np.array(list(map(lambda x: (100*np.square(x[1]-np.square(x[0]))+np.square(x[0]-1)), xy))).reshape(1,-1)

# %%
plot_output(xy,rosenbrock, "rosenbrock-original")
